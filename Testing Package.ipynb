# %%
pip install .
# Out:
# Processing ./.
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for preprocess_elizabeth: filename=preprocess_elizabeth-0.1-py3-none-any.whl size=10034 sha256=59a778f945a2389b495522ef97f86f717a174e4f90ffe8667645a3d8058d9839
#   Stored in directory: /Users/lizke/Library/Caches/pip/wheels/bc/ad/36/4bd7cfc6b263bfd2115fa3e4fa8cbce48e9a3aee5d4fc6e55c
# Successfully built preprocess_elizabeth
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show preprocess_elizabeth
# Out:
# Name: preprocess_elizabeth
# Version: 0.1
# Summary: This is a text preprocessing package
# Home-page:
# Author: Elizabeth Bekele
# Author-email: elizabethbekele07@gmail.com
# License:
# Location: /Users/lizke/opt/anaconda3/envs/audio/lib/python3.13/site-packages
# Requires:
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Testing After Installation

# %%
import preprocess_elizabeth as pe

# when you use this library for the first time
pe.download_nltk_packages()

# %%
pe.word_count('some text data')
# Out:
# 3

# %%
pe.char_count('some text data')
# Out:
# 12

# %%
pe.avg_word_len('some text data')
# Out:
# 4.0

# %%
pe.stop_words_count('some text data')
# Out:
# 1

# %%
pe.mentions_count('some text @data')
# Out:
# 1

# %%
pe.upper_case_count('SOME text data')
# Out:
# 1

# %%
pe.count_rt('some TEXT @data RT @laxmi')
# Out:
# 1

# %%
pe.remove_rt('some TEXT @data RT @laxmi')
# Out:
# 'some TEXT @data  '

# %%
pe.remove_html_tags('<p> some TEXT @data RT @laxmi</p>')
# Out:
# ' some TEXT @data RT @laxmi'

# %%
pe.remove_rt('<p> some TEXT @data RT @laxmi</p>')
# Out:
# '<p> some TEXT @data  </p>'

# %%
pe.remove_special_chars('<p> some TEXT @data RT @laxmi</p>')
# Out:
# 'p some TEXT data RT laxmip'

# %%
x = 'The dogs are playing with cats'
pe.lemmatize_noun_verb(x)
# Out:
# 'The dog are play with cat'

# %%
pe.lemmatize(x)
# Out:
# 'the dog be play with cat'

# %%
x = 'The dgs are playin with cats'
pe.correct_spelling(x)

# playin
# plain (remove one character)
# playing (add one character)
# Out:
# 'The dogs are plain with cats'

# %%
x = 'Food came out in a timely manner. The biscuits were amazing. As a chef in the industry for 15+ years, the food was outstanding.'
pe.get_noun_phrase(x)
# Out:
# WordList(['timely manner', '15+ years'])

# %%
pe.translate(x, target='fr-FR')
# Out:
# "La nourriture est sortie en temps opportun. Les biscuits étaient incroyables. En tant que chef dans l'industrie depuis plus de 15ans, la nourriture était exceptionnelle."

# %%
pe.translate(x, target='it-IT')
# Out:
# 'Il cibo usciva in modo tempestivo. I biscotti erano fantastici. Come chef nel settore da oltre 15 anni, il cibo era eccezionale.'

# %%
# %cd "/Users/lizke/Documents/Udemy/nlp-for-beginners-udemy"
# Out:
# /Users/lizke/Documents/Udemy/nlp-for-beginners-udemy

# %%
# %pwd
# Out:
# '/Users/lizke/Documents/Udemy/nlp-for-beginners-udemy'
